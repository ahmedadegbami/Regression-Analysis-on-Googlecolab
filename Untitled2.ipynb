# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedadegbami/Regression-Analysis-on-Googlecolab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2b1db1c8-8987-4113-87df-e7a95a4e8a24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b1db1c8-8987-4113-87df-e7a95a4e8a24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data1.csv to Data1.csv

# %%
data = pd.read_csv("Data1.csv")
X = data.iloc[:,0].values.reshape(-1,1)
Y1 = data.iloc[:,1].values.reshape(-1,1)
lr = LinearRegression()
lr.fit(X,Y1)
Y1_pred = lr.predict(X)

# %%
plt.scatter(X,Y1)
plt.plot(X, Y1_pred, color='red')
plt.title('SMOKING vs TIME')
plt.xlabel('Smoking')
plt.ylabel('Time')
plt.show()

# %%
data = pd.read_csv("Data1.csv")
X = data.iloc[:,0].values.reshape(-1,1)
Y2 = data.iloc[:,2].values.reshape(-1,1)
lr = LinearRegression()
lr.fit(X,Y2)
Y2_pred = lr.predict(X)

# %%
plt.scatter(X,Y2)
plt.plot(X, Y2_pred, color='red')
plt.title('SMOKING vs TIME')
plt.xlabel('Smoking')
plt.ylabel('Male')
plt.show()

# %%
data = pd.read_csv("Data1.csv")
X = data.iloc[:,0].values.reshape(-1,1)
Y3 = data.iloc[:,3].values.reshape(-1,1)
lr = LinearRegression()
lr.fit(X,Y3)
Y3_pred = lr.predict(X)

# %%
plt.scatter(X,Y3)
plt.plot(X, Y3_pred, color='red')
plt.title('SMOKING vs TIME')
plt.xlabel('Smoking')
plt.ylabel('Female')
plt.show()
